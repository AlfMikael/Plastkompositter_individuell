# %%
from lib import matlib
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np

# %%
matlib
# Out:
# <module 'lib.matlib' from 'C:\\Users\\Alf\\Programmering\\Plastkompositter_individuell\\lib\\matlib.py'>

# %%
def illustrateCurvatures(Kx,Ky,Kxy):
    from mpl_toolkits.mplot3d import Axes3D
    import matplotlib.pyplot as plt
    from matplotlib import cm
    from matplotlib.ticker import LinearLocator, FormatStrFormatter
    import numpy as np
    fig = plt.figure(figsize=(6,4))
    #ax = fig.gca(projection='3d') # fixed deprication warning
    ax = fig.add_subplot(projection='3d')
    X = np.arange(-0.5, 0.6, 0.1)
    Y = np.arange(-0.5, 0.6, 0.1)
    X, Y = np.meshgrid(X, Y)
    Z1 =  (- Kx*X**2 - Ky*Y**2 - Kxy*X*Y)/2
    surf1 = ax.plot_surface(X, Y, Z1, cmap=cm.coolwarm, linewidth=0, antialiased=False)

# %%
illustrateCurvatures(Kx=0.5, Ky=0.0, Kxy=0.0)

# %%
illustrateCurvatures(Kx=0, Ky=0.5, Kxy=0)

# %%
illustrateCurvatures(Kx=0.0, Ky=0.0, Kxy=-0.15)

# %%
illustrateCurvatures(Kx=0.25, Ky=0.25, Kxy=0)

# %%
illustrateCurvatures(Kx=0.25, Ky=-0.25, Kxy=0)

# %%
illustrateCurvatures(Kx=0.25, Ky=0.25, Kxy=-0.25)
